# %% [markdown]
# # PA 3: Association Analysis - Apriori Algorithm

# %% [markdown]
# ## Student Details
#
# Student Name and ID: Priyanka Ramdas Wakte

# %% [markdown]
# ## - - - - - - - - - - - - - - - - - - - - - - - SOLUTION - - - - - - - - - - - - - - - - - - - - - - -

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# Import your Libraries

import pandas as pd
import csv
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Task 1: DataSet Preprocess
# Before you start you need to modify your dataset 'dataset_group.csv' to look like the toyDS.csv.  Each transaction is at one line with a variable length.  Discard the date attribute (1st attribute) from your dataset.  For example, in your dataset transaction#4 should look like:
#
#     cereals,juice,lunch meat,soda,toilet paper,all-purpose
#
# Export your modified dataset in a file named 'dataset.csv'.
#
# Use pandas to Read and Print the first 7 transactions of the 'dataset.csv'.

# %%
from IPython.display import Image
print ('ScreenShot of the toyDS.csv')
Image("SampleScreen01.png")
# Out:
# ScreenShot of the toyDS.csv

# %%
# # # # # # # # #  Code for Task 1 # # # # # # # # #
df_dt = pd.read_csv('dataset_group.csv', header=None)
df_dt.columns = ['Trans_date','Trans_No','Item'] # Adding Column Names to the dataset
df_dt1 = df_dt.drop(['Trans_date'], axis = 1) # Dropping the date column in order to look like fruits dataset
df_dt2 = df_dt1.groupby('Trans_No')['Item'].apply(', '.join).reset_index() # Re shaping the dataframe
df_dt3 = pd.DataFrame(df_dt2['Item'].str.split(',').tolist()) #Reshaping the dataframe
df_dt3.to_csv('dataset.csv', header=False, index=False) # Exporting the modified dataset to dataset_updated.csv

# %%
# # #  Solution  # # #
df_dt4 = pd.read_csv('dataset.csv', header=None) # Saving the modified dataset to pandas dataframe
df_dt4.head(7)
# Out:
#                   0              1               2              3   \
# 0             yogurt           pork   sandwich bags     lunch meat
# 1       toilet paper        shampoo       hand soap        waffles
# 2               soda           pork            soap      ice cream
# 3            cereals          juice      lunch meat           soda
# 4    sandwich loaves          pasta       tortillas          mixes
# 5  laundry detergent   toilet paper            eggs   toilet paper
# 6   individual meals   paper towels       tortillas     vegetables
#
#               4              5                              6   \
# 0   all- purpose          flour                           soda
# 1     vegetables        cheeses                          mixes
# 2   toilet paper   dinner rolls                      hand soap
# 3   toilet paper   all- purpose                            NaN
# 4      hand soap   toilet paper                     vegetables
# ...

# %% [markdown]
# ### Task 2: Run apriory.py and Evaluate Results
#
# In this task, you have to find how you will be able to execute and print apriory results by making use only the apriory.py. In other words "DO NOT USE ANY OTHER LIBRARY FOR TASK 2!!!".
#
# (*) For those that are not familiar with python and coding this could be a quite demanding task.
#
#
# You will have to execute apriori algorithm "3" times for different combinations of support and confidence.
# Print the results of apriory for 'dataset.csv' by making use ONLY the provided methods.
#
# Do not forget to add your reasoning (explain the result outcome) at the top of each case in a nice and readable way.
#
# You are allowed to use the python print method to print your results. DO NOT add your reasoning as comments.

# %%
print ('# # # # # # # # #  Code for Task 2, Case:1 # # # # # # # # #') 
print ('Case 1 (minimum support=0.3 and minimum confidence=0.7)')
print ('Case 1 Reasoning: The total number of items obtained is 41, and the total number of rules obtained is 3,'
 + 'when the minimal support and minimum confidence parameters are set to 0.3 and 0.7, respectively.' +
 'As a result, we can conclude that 41 things are more commonly purchased, as well as' +
 'We found three association rules that have a higher confidence level than the minimal.' +
 'we can see from the output that the item:vegetables has the most support, 0.716.' +
 'This means that vegetables are purchased more frequently than other items.' +
 'Rule(eggs=>vegetables) has the highest confidence among the rules or association rules.' +
 'This demonstrates that eggs are frequently purchased with veggies.' +
 'remaining items like yogurt, poultry' +
 'Along with vegetables, they are the second and third most often purchased items.' +
 'Finally, we can determine that eggs and poultry should be sold near vegetables in order to increase sales.')
print ('Case 1 Output:')
# %run apriori.py -f dataset.csv -s 0.3 -c 0.7
print("Total No. of Items:", len(items))
print("Total No. of Rules:", len(rules))
print ('Case 1 Visualization: Graph & Observations')
print('Observations: We also notice that vegetables receive the most support. The graph depicts the level of support and confidence in various vegetable pairings with other foods such as poultry, eggs, and yogurt.')
sp = []
cf = []
for i in items:
    sp.append(i[1])
for r in rules:
    cf.append(r[1])

l = min(len(sp),len(cf))
plt.scatter(cf[0:l],sp[0:l],alpha=0.5, marker='*')
plt.title('Confidence Vs Support')
plt.xlabel('Support')
plt.ylabel('Confidence')
plt.show()
# Out:
# # # # # # # # # #  Code for Task 2, Case:1 # # # # # # # # #
# Case 1 (minimum support=0.3 and minimum confidence=0.7)
# ...

# %%
print ('# # # # # # # # #  Code for Task 2, Case:2 # # # # # # # # #') 
print ('Case 2 (minimum support=0.15 and minimum confidence=0.7)') 
print ('Case 2 Reasoning:When the parameters minimum support and minimum confidence are set to 0.15 and 0.7,'+' the number of items and rules obtained are 273 and 38, respectively.'+'When comparing the output to previous results, we can see that many items have a score of less than 0.3,'+'indicating that they are less frequently purchased with vegetables.As a result,'+'they are not need to be positioned together.\nBut there is another new rule poultry and dinner rolls must be served with veggies.\nSo even dinner rolls can be kept filled with meat and vegetables.')
print ('Case 2 Output:') 
# %run apriori.py -f dataset.csv -s 0.15 -c 0.7
print("Total no. of Items:", len(items))
print("Total no. of Rules:", len(rules))
print ('Case 2 Visualization: Graph & Observations')
print('Observations:We can see that there are a lot of items that are close to 0.150 support, but they can not be considered because their association is not strong enough. Even in this scenario, we see that veggies have the most support. Sugar and dinner rolls have strong support and confidence scores, according to our findings.')
sp = []
cf = []
for i in items:
    sp.append(item[1])
for r in rules:
    cf.append(rule[1])

l = min(len(sp),len(cf))
plt.scatter(cf[0:l],sp[0:l],alpha=0.5, marker='*')
plt.title('Confidence Vs Support')
plt.xlabel('Support')
plt.ylabel('Confidence')
plt.show()
# Out:
# # # # # # # # # #  Code for Task 2, Case:2 # # # # # # # # #
# Case 2 (minimum support=0.15 and minimum confidence=0.7)
# Case 2 Reasoning:When the parameters minimum support and minimum confidence are set to 0.15 and 0.7, the number of items and rules obtained are 273 and 38, respectively.When comparing the output to previous results, we can see that many items have a score of less than 0.3,indicating that they are less frequently purchased with vegetables.As a result,they are not need to be positioned together.
# But there is another new rule poultry and dinner rolls must be served with veggies.
# So even dinner rolls can be kept filled with meat and vegetables.
# Case 2 Output:
#
# ------------ITEMS-----------------
# item: (' laundry detergent', ' ketchup') , 0.150
# item: (' soda', ' spaghetti sauce') , 0.150
# item: (' soda', ' toilet paper') , 0.150
# item: (' milk', ' mixes') , 0.150
# item: (' ice cream', ' cereals') , 0.150
# item: (' yogurt', ' sugar') , 0.150
# ...

# %%
print ('# # # # # # # # #  Code for Task 2, Case:3 # # # # # # # # #') 
print ('Case 3 (minimum support=XX and minimum confidence=YY)')
print ('Case 3 Reasoning:For the lowest minimal support of 0.1 and the highest minimum confidence of 0.8, we get 1391 items and 448 rules. For this, we receive a large number of objects and rules. However, we can observe that the combination of vegetables, yogurt, chicken, and eggs is linked to new things such as sugar, dinner rolls, and sandwich loaves. However, their support is insufficient, and they do not need to be stocked together.')
print ('Case 3 Output:')
# %run apriori.py -f dataset.csv -s 0.1 -c 0.8
print("Total Items:", len(items))
print("Total Rules:", len(rules))
print ('Case 3 Visualization: Graph & Observations')
print('Observations: There are many rules with a minimum confidence of 0.8 for lower support values of 0.1. There are fewer rules associated with confidence larger than 0.8 if we boost the support a little. The number of associations decreases as support grows. As we reduce support, the associations get stronger.')
sp = []
cf = []
for i in items:
    sp.append(i[1])
for r in rules:
    cf.append(r[1])

l = min(len(sp),len(cf))
plt.scatter(cf[0:l],sp[0:l],alpha=0.5, marker='*')
plt.title('Confidence Vs Support')
plt.xlabel('Support')
plt.ylabel('Confidence')
plt.show()
# Out:
# # # # # # # # # #  Code for Task 2, Case:3 # # # # # # # # #
# Case 3 (minimum support=XX and minimum confidence=YY)
# Case 3 Reasoning:For the lowest minimal support of 0.1 and the highest minimum confidence of 0.8, we get 1391 items and 448 rules. For this, we receive a large number of objects and rules. However, we can observe that the combination of vegetables, yogurt, chicken, and eggs is linked to new things such as sugar, dinner rolls, and sandwich loaves. However, their support is insufficient, and they do not need to be stocked together.
# Case 3 Output:
#
# ------------ITEMS-----------------
# item: (' ice cream', ' vegetables', ' pork') , 0.100
# item: (' milk', ' vegetables', ' pork') , 0.100
# item: (' vegetables', ' toilet paper', ' pasta') , 0.100
# item: (' vegetables', ' fruits', ' hand soap') , 0.100
# item: (' vegetables', ' sandwich bags', ' hand soap') , 0.101
# item: (' vegetables', ' tortillas', ' hand soap') , 0.101
# ...

# %% [markdown]
# ## Report
# (separately in pdf)

# %% [markdown]
# Take a small dataset (it can be any dataset). Show 3 support and confidence for the small dataset. Show the rules for all the 3 cases using the formula.
# Provide references where ever necessary.

# %% [markdown]
# # References
#
# [01] https://www.kaggle.com/acostasg/random-shopping-cart
#
# [02] https://github.com/asaini/Apriori

# %% [markdown]
# # Rubric
# * [02 points] - Student Details
# * [08 points] - Comply with submission instructions
# * [30 points] - DataSet Preprocess
# * [30 points] - Run apriory.py
# * [5 points] - Evaluate Results
# * [25 points] - Report
